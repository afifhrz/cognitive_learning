# %% [markdown]
# # Preparation

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

# %%
data = pd.read_excel("../0_dataset_master/Experiment_edited_V6.xlsx")

# %% [markdown]
# # Fatigue Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Fatigue_PhysicalExertion',
    'Fatigue_PhysicalDiscomfort', 'Fatigue_LackofMotivation',
    'Fatigue_Sleepiness', 'Fatigue_LackofEnergy'
    ]
group = ['Thermal', 'Traffic noise levels']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar',
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\2222185884.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(

# %% [markdown]
# # Mood Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mood_tense', 'Mood_angry', 'Mood_fatigued', 'Mood_depressed',
    'Mood_vigorous', 'Mood_confused',
    ]
group = ['Thermal', "Traffic noise levels"]
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar',
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1562311607.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(

# %% [markdown]
# # Workload

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mental demand', 'Physical demand',
    'Temporal demand', 'Performance', 'Effort', 'Frustration',
    ]
group = ['Thermal', 'Traffic noise levels']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar',
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_11440\1175624978.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(

# %% [markdown]
# # Preparation

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

# %%
data = pd.read_excel("../0_dataset_master/Experiment_edited_V6.xlsx")

# %% [markdown]
# # Fatigue Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Fatigue_PhysicalExertion',
    'Fatigue_PhysicalDiscomfort', 'Fatigue_LackofMotivation',
    'Fatigue_Sleepiness', 'Fatigue_LackofEnergy'
    ]
col_x_labels = [
    'Fatigue Physical Exertion',
    'Fatigue Physical Discomfort', 'Fatigue Lack of Motivation',
    'Fatigue Sleepiness', 'Fatigue Lack of Energy'
]
group = ['Thermal', 'Traffic noise levels']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    g = sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar', errorbar=None, width=0.6,
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
    for id, ax in enumerate(g.axes_dict.items()):
        if id == 0:
            ax[1].set_xticklabels(["AC Fan Off"])
        else:
            ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
    plt.subplots_adjust(wspace=0)
    g.set_axis_labels("", col_x_labels[index])
    plt.yticks(ticks = [1,2,3,4,5], labels=[1,2,3,4,5])
    plt.show(g)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\3145753090.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])

# %% [markdown]
# # Mood Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mood_tense', 'Mood_angry', 'Mood_fatigued', 'Mood_depressed',
    'Mood_vigorous', 'Mood_confused',
    ]
col_x_labels = [
    'Mood Tense', 'Mood Angry', 'Mood Fatigued', 'Mood Depressed',
    'Mood Vigorous', 'Mood Confused',
    ]
group = ['Thermal', "Traffic noise levels"]
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    g = sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar', errorbar=None, width=0.6,
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
    for id, ax in enumerate(g.axes_dict.items()):
        if id == 0:
            ax[1].set_xticklabels(["AC Fan Off"])
        else:
            ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
    plt.subplots_adjust(wspace=0)
    g.set_axis_labels("", col_x_labels[index])
    plt.yticks(ticks = [1,2,3,4,5], labels=[1,2,3,4,5])
    plt.show(g)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\78201526.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])

# %% [markdown]
# # Workload

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mental demand', 'Physical demand',
    'Temporal demand', 'Performance', 'Effort', 'Frustration',
    ]
col_x_labels = [
    'Mental demand', 'Physical demand',
    'Temporal demand', 'Performance', 'Effort', 'Frustration',
    ]
group = ['Thermal', 'Traffic noise levels']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

for index, item in enumerate(col_x):
    g = sns.catplot(
        data=data_fat, 
        x='Thermal', 
        y=item,
        col='Traffic noise levels', kind='bar', width=.6, errorbar=None,
        palette=sns.color_palette(['blue','green','orange','red']),
        facet_kws={'gridspec_kws':{'width_ratios': [1, 4, 4]}},
        sharex=False,
        legend=False
    )
    for id, ax in enumerate(g.axes_dict.items()):
        if id == 0:
            ax[1].set_xticklabels(["AC Fan Off"])
        else:
            ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
    plt.subplots_adjust(wspace=0)
    g.set_axis_labels("", col_x_labels[index])
    plt.yticks(ticks = [1,2,3,4,5,6,7], labels=[1,2,3,4,5,6,7])
    plt.show(g)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_16360\1036870864.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"])

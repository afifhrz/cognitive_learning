# %% [markdown]
# # Preparation

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

# %%
data = pd.read_excel("../0_dataset_master/Experiment_edited_V6.xlsx")
data.columns
# Out:
# Index(['Unnamed: 0', 'No', 'Start Date', 'End Date', 'IP Address', 'Progress',
#        'Duration (in seconds)', 'Finished', 'Recorded Date', 'Response ID',
#        'Experiment set', 'Experiment id', 'subid',
#        'Type your set and ID number. \n\nFor example: set3-ID2',
#        'Time\n\nFor example 11:30 AM', 'Thermal', 'Traffic noise levels',
#        'Speech', 'Time_thermal', 'v', 'v_adj', 'T', 'H', 'Tgl', 'CO2', 'PM2.5',
#        'Mood_tense', 'Mood_angry', 'Mood_fatigued', 'Mood_depressed',
#        'Mood_vigorous', 'Mood_confused', 'Fatigue_PhysicalExertion',
#        'Fatigue_PhysicalDiscomfort', 'Fatigue_LackofMotivation',
#        'Fatigue_Sleepiness', 'Fatigue_LackofEnergy', 'Rotation1',
#        'SpatialSpan1', 'FeatureMatch1', 'DoubleTrouble1', 'Rotation2',
#        'SpatialSpan2', 'FeatureMatch2', 'DoubleTrouble2', 'Rotation_average',
#        'SpatialSpan_average', 'FeatureMatch_average', 'DoubleTrouble_average',
# ...

# %% [markdown]
# # Fatigue Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Fatigue_PhysicalExertion',
    'Fatigue_PhysicalDiscomfort', 'Fatigue_LackofMotivation',
    'Fatigue_Sleepiness', 'Fatigue_LackofEnergy'
    ]
group = ['Thermal']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

fig, axes = plt.subplots(1, len(col_x), figsize=(25, 5), sharey=True)
fig.suptitle('Fatigue Performance')

for index, item in enumerate(col_x):
    sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
    axes[index].set_title(item)

plt.legend(title='Thermal', loc='center right', labels=["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"], bbox_to_anchor=(1.25,.5), handles=[blue_patch, green_patch, orange_patch, red_patch])
plt.show(fig)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\423624482.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\423624482.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\423624482.py:22: FutureWarning:
#
# ...

# %% [markdown]
# # Mood Plot

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mood_tense', 'Mood_angry', 'Mood_fatigued', 'Mood_depressed',
    'Mood_vigorous', 'Mood_confused',
    ]
group = ['Thermal']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

fig, axes = plt.subplots(1, len(col_x), figsize=(25, 5), sharey=True)
fig.suptitle('Mood Performance')

for index, item in enumerate(col_x):
    sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
    axes[index].set_title(item)

plt.legend(title='Thermal', loc='center right', labels=["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"], bbox_to_anchor=(1.25,.5), handles=[blue_patch, green_patch, orange_patch, red_patch])
plt.show(fig)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\438481637.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\438481637.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\438481637.py:21: FutureWarning:
#
# ...

# %% [markdown]
# # Cognitive??

# %%
blue_patch = mpatches.Patch(color='blue', label="AC Fan Off")
green_patch = mpatches.Patch(color='green', label="NV Fan 60%")
orange_patch = mpatches.Patch(color='orange', label="NV Fan 40%")
red_patch = mpatches.Patch(color='red', label="NV Fan Off")

col_x = [
    'Mental demand', 'Physical demand',
    'Temporal demand', 'Performance', 'Effort', 'Frustration',
    ]
group = ['Thermal']
data_fat = data[col_x+group]

custom_dict = {'AC':1, 'NV fan 5':2, 'NV fan 3':3,'NV fan 0':4,} 
data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
data_fat.reset_index(inplace=True)

fig, axes = plt.subplots(1, len(col_x), figsize=(25, 5), sharey=True)
fig.suptitle('Cognitive Performance')

for index, item in enumerate(col_x):
    sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
    axes[index].set_title(item)

plt.legend(title='Thermal', loc='center right', labels=["AC Fan Off","NV Fan 60%", "NV Fan 40%", "NV Fan Off"], bbox_to_anchor=(1.25,.5), handles=[blue_patch, green_patch, orange_patch, red_patch])
plt.show(fig)
# Out:
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\3378807726.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fat.sort_values(by=['Thermal'], key=lambda x: x.map(custom_dict), inplace=True)
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\3378807726.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[index], data=data_fat, x="Thermal", y=item, palette=sns.color_palette(['blue','green','orange','red']))
# C:\Users\ZENI\AppData\Local\Temp\ipykernel_10156\3378807726.py:21: FutureWarning:
#
# ...
